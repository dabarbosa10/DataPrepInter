# %% [markdown]
# <a href="https://colab.research.google.com/github/dabarbosa10/DataPrepInter/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

# %%
import pandas as pd

# %%
my_dict={
    'country':names,
    'drives_right':dr,
    'cars_per_cap':cpc
}

# %%
cars=pd.DataFrame(my_dict)

# %%
cars
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45

# %%
row_labels = ['US', 'AUS', 'JPN', 'IN', 'RU', 'MOR', 'EG']
cars.index=row_labels

# %%
cars
# Out:
#            country  drives_right  cars_per_cap
# US   United States          True           809
# AUS      Australia         False           731
# JPN          Japan         False           588
# IN           India         False            18
# RU          Russia          True           200
# MOR        Morocco          True            70
# EG           Egypt          True            45

# %%
cars['country']
# Out:
# US     United States
# AUS        Australia
# JPN            Japan
# IN             India
# RU            Russia
# MOR          Morocco
# EG             Egypt
# Name: country, dtype: object

# %%
cars[['country']]
# Out:
#            country
# US   United States
# AUS      Australia
# JPN          Japan
# IN           India
# RU          Russia
# MOR        Morocco
# EG           Egypt

# %%
cars.loc[["RU","AUS"],["country","cars_per_cap"]]
# Out:
#        country  cars_per_cap
# RU      Russia           200
# AUS  Australia           731

# %%
cars.loc[:, ["country"]]
# Out:
#            country
# US   United States
# AUS      Australia
# JPN          Japan
# IN           India
# RU          Russia
# MOR        Morocco
# EG           Egypt

# %%
"carl"<"diego"
# Out:
# True

# %%
import numpy as np
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# %%
my_house[my_house>=18]
# Out:
# array([18., 20.])

# %%
my_house[my_house<your_house]
# Out:
# array([20.  , 10.75])

# %%
my_house>=18
# Out:
# array([ True,  True, False, False])

# %%
bmi=np.array([21.852, 20.975, 21.75, 24.747, 21.441])

# %%
bmi>21
# Out:
# array([ True, False,  True,  True,  True])

# %%
bmi<22
# Out:
# array([ True,  True,  True, False,  True])

# %%
np.logical_and(bmi>21, bmi<22)
# Out:
# array([ True, False,  True, False,  True])

# %%
bmi[np.logical_and(bmi>21, bmi<22)]
# Out:
# array([21.852, 21.75 , 21.441])

# %%
#lets work with this numpy arrays

# %%
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# %%
np.logical_or(my_house>18.5, my_house<10)
# Out:
# array([False,  True, False,  True])

# %%
np.logical_and(my_house<11, your_house<11)
# Out:
# array([False, False, False,  True])

# %% [markdown]
# dataframe["area"]>8
#
# is_huge=dataframe["area"]>8
#
# dataframe[is_huge]

# %%
cars
# Out:
#            country  drives_right  cars_per_cap
# US   United States          True           809
# AUS      Australia         False           731
# JPN          Japan         False           588
# IN           India         False            18
# RU          Russia          True           200
# MOR        Morocco          True            70
# EG           Egypt          True            45

# %%
cars[np.logical_and(cars['cars_per_cap']>200, cars['cars_per_cap']<800)]
# Out:
#        country  drives_right  cars_per_cap
# AUS  Australia         False           731
# JPN      Japan         False           588

# %%
dr=cars['drives_right']

# %%
dr
# Out:
# US      True
# AUS    False
# JPN    False
# IN     False
# RU      True
# MOR     True
# EG      True
# Name: drives_right, dtype: bool

# %%
cars[dr]
# Out:
#            country  drives_right  cars_per_cap
# US   United States          True           809
# RU          Russia          True           200
# MOR        Morocco          True            70
# EG           Egypt          True            45

# %%
for index, value in enumerate(cpc):
  print(f'The index is {index} and the value is {value}')
# Out:
# The index is 0 and the value is 809
# The index is 1 and the value is 731
# The index is 2 and the value is 588
# The index is 3 and the value is 18
# The index is 4 and the value is 200
# The index is 5 and the value is 70
# The index is 6 and the value is 45

# %%
#Now lets take a string
st="Hello World"
for index, character in enumerate(st):
  print(f'The index is {index} and the character is {character}')
# Out:
# The index is 0 and the character is H
# The index is 1 and the character is e
# The index is 2 and the character is l
# The index is 3 and the character is l
# The index is 4 and the character is o
# The index is 5 and the character is
# The index is 6 and the character is W
# The index is 7 and the character is o
# The index is 8 and the character is r
# The index is 9 and the character is l
# The index is 10 and the character is d
